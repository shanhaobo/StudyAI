# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
import gym

# Hyperparameters
learning_rate = 0.0005
gamma = 0.98
lmbda = 0.95
eps_clip = 0.1
K_epochs = 3
T_horizon = 20

# %%
class PPO(nn.Module):
    def __init__(self):
        super(PPO, self).__init__()
        self.data = []

        self.fc1 = nn.Linear(4, 256)
        self.fc_pi = nn.Linear(256, 2)
        self.fc_v = nn.Linear(256, 1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self, x, softmax_dim=0):
        x = torch.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = torch.softmax(x, dim=softmax_dim)
        return prob

    def v(self, x):
        x = torch.relu(self.fc1(x))
        v = self.fc_v(x)
        return v

    def put_data(self, transition):
        self.data.append(transition)

    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []
        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition

            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            prob_a_lst.append([prob_a])
            done_mask = 0 if done else 1
            done_lst.append([done_mask])

        s_batch, a_batch, r_batch, s_prime_batch, prob_a_batch, done_batch = (
            torch.tensor(s_lst, dtype=torch.float),
            torch.tensor(a_lst),
            torch.tensor(r_lst),
            torch.tensor(s_prime_lst, dtype=torch.float),
            torch.tensor(prob_a_lst, dtype=torch.float),
            torch.tensor(done_lst, dtype=torch.float),
        )
        self.data = []
        return s_batch, a_batch, r_batch, s_prime_batch, prob_a_batch, done_batch

    def train_net(self):
        s, a, r, s_prime, prob_a, done = self.make_batch()

        for _ in range(K_epochs):
            td_target = r + gamma * self.v(s_prime) * done
            delta = td_target - self.v(s)
            delta = delta.detach().numpy()

            advantage_lst = []
            advantage = 0.0
            for delta_t in delta[::-1]:
                advantage = gamma * lmbda * advantage + delta_t[0]
                advantage_lst.append([advantage])
            advantage_lst.reverse()
            advantage = torch.tensor(advantage_lst, dtype=torch.float)

            pi = self.pi(s, softmax_dim=1)
            pi_a = pi.gather(1, a)
            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))

            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1 - eps_clip, 1 + eps_clip) * advantage
            loss = -torch.min(surr1, surr2
                + 0.5 * torch.nn.functional.mse_loss(self.v(s), td_target.detach())
                - 0.01 * pi_a.mean()
            )

        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()
# Out:
# C:\Users\shanhaobo\AppData\Local\Temp\ipykernel_18880\1063749837.py:39: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   torch.tensor(s_lst, dtype=torch.float),
# # of episode: 20, avg score: 19.5
# # of episode: 40, avg score: 22.6
# # of episode: 60, avg score: 23.1
# # of episode: 80, avg score: 21.0
# # of episode: 100, avg score: 14.1
# # of episode: 120, avg score: 16.1
# # of episode: 140, avg score: 14.8
# # of episode: 160, avg score: 13.6
# # of episode: 180, avg score: 12.9
# # of episode: 200, avg score: 11.6
# # of episode: 220, avg score: 11.7
# # of episode: 240, avg score: 11.6
# # of episode: 260, avg score: 12.2
# # of episode: 280, avg score: 12.2
# # of episode: 300, avg score: 13.1
# # of episode: 320, avg score: 13.1
# # of episode: 340, avg score: 12.7
# # of episode: 360, avg score: 13.9
# # of episode: 380, avg score: 12.3
# # of episode: 400, avg score: 12.2
# # of episode: 420, avg score: 11.8
# # of episode: 440, avg score: 12.9
# # of episode: 460, avg score: 11.2
# # of episode: 480, avg score: 10.4
# # of episode: 500, avg score: 10.6
# # of episode: 520, avg score: 11.7
# # of episode: 540, avg score: 11.4
# # of episode: 560, avg score: 11.6
# # of episode: 580, avg score: 10.8
# # of episode: 600, avg score: 12.5
# # of episode: 620, avg score: 11.2
# # of episode: 640, avg score: 10.4
# # of episode: 660, avg score: 10.5
# # of episode: 680, avg score: 11.2
# # of episode: 700, avg score: 9.9
# # of episode: 720, avg score: 11.0
# # of episode: 740, avg score: 10.2
# # of episode: 760, avg score: 10.8
# # of episode: 780, avg score: 11.0
# # of episode: 800, avg score: 10.9
# # of episode: 820, avg score: 10.6
# # of episode: 840, avg score: 10.4
# # of episode: 860, avg score: 10.6
# # of episode: 880, avg score: 9.8
# # of episode: 900, avg score: 9.9
# # of episode: 920, avg score: 9.4
# # of episode: 940, avg score: 9.6
# # of episode: 960, avg score: 9.7
# # of episode: 980, avg score: 10.2
# # of episode: 1000, avg score: 10.6
# # of episode: 1020, avg score: 10.2
# # of episode: 1040, avg score: 10.7
# # of episode: 1060, avg score: 10.0
# # of episode: 1080, avg score: 11.2
# # of episode: 1100, avg score: 11.5
# # of episode: 1120, avg score: 10.8
# # of episode: 1140, avg score: 11.4
# # of episode: 1160, avg score: 11.1
# # of episode: 1180, avg score: 11.4
# # of episode: 1200, avg score: 11.7
# # of episode: 1220, avg score: 12.3
# # of episode: 1240, avg score: 11.1
# # of episode: 1260, avg score: 10.4
# # of episode: 1280, avg score: 11.0
# # of episode: 1300, avg score: 10.7
# # of episode: 1320, avg score: 11.2
# # of episode: 1340, avg score: 10.2
# # of episode: 1360, avg score: 11.2
# # of episode: 1380, avg score: 11.2
# # of episode: 1400, avg score: 10.9
# # of episode: 1420, avg score: 10.5
# # of episode: 1440, avg score: 10.6
# # of episode: 1460, avg score: 10.9
# # of episode: 1480, avg score: 10.9
# # of episode: 1500, avg score: 10.7
# # of episode: 1520, avg score: 10.5
# # of episode: 1540, avg score: 10.9
# # of episode: 1560, avg score: 11.3
# # of episode: 1580, avg score: 11.4
# # of episode: 1600, avg score: 10.7
# # of episode: 1620, avg score: 10.5
# # of episode: 1640, avg score: 10.9
# # of episode: 1660, avg score: 10.3
# # of episode: 1680, avg score: 11.1
# # of episode: 1700, avg score: 10.0
# # of episode: 1720, avg score: 10.2
# # of episode: 1740, avg score: 10.3
# # of episode: 1760, avg score: 9.9
# # of episode: 1780, avg score: 9.4
# # of episode: 1800, avg score: 9.9
# # of episode: 1820, avg score: 10.2
# # of episode: 1840, avg score: 9.5
# # of episode: 1860, avg score: 10.1
# # of episode: 1880, avg score: 9.7
# # of episode: 1900, avg score: 9.8
# # of episode: 1920, avg score: 9.9
# # of episode: 1940, avg score: 9.4
# # of episode: 1960, avg score: 9.8
# # of episode: 1980, avg score: 9.8
# # of episode: 2000, avg score: 9.7
# # of episode: 2020, avg score: 9.7
# # of episode: 2040, avg score: 9.2
# # of episode: 2060, avg score: 9.8
# # of episode: 2080, avg score: 9.4
# # of episode: 2100, avg score: 9.6
# # of episode: 2120, avg score: 9.4
# # of episode: 2140, avg score: 9.4
# # of episode: 2160, avg score: 9.3
# # of episode: 2180, avg score: 9.2
# # of episode: 2200, avg score: 9.5
# # of episode: 2220, avg score: 9.3
# # of episode: 2240, avg score: 9.2
# # of episode: 2260, avg score: 9.5
# # of episode: 2280, avg score: 9.4
# # of episode: 2300, avg score: 9.4
# # of episode: 2320, avg score: 9.2
# # of episode: 2340, avg score: 9.7
# # of episode: 2360, avg score: 9.4
# # of episode: 2380, avg score: 9.4
# # of episode: 2400, avg score: 9.3
# # of episode: 2420, avg score: 9.4
# # of episode: 2440, avg score: 9.3
# # of episode: 2460, avg score: 9.5
# # of episode: 2480, avg score: 9.0
# # of episode: 2500, avg score: 9.4
# # of episode: 2520, avg score: 9.4
# # of episode: 2540, avg score: 9.3
# # of episode: 2560, avg score: 9.4
# # of episode: 2580, avg score: 9.6
# # of episode: 2600, avg score: 9.3
# # of episode: 2620, avg score: 9.4
# # of episode: 2640, avg score: 9.4
# # of episode: 2660, avg score: 9.8
# # of episode: 2680, avg score: 9.0
# # of episode: 2700, avg score: 9.2
# # of episode: 2720, avg score: 9.1
# # of episode: 2740, avg score: 9.4
# # of episode: 2760, avg score: 9.2
# # of episode: 2780, avg score: 9.9
# # of episode: 2800, avg score: 9.1
# # of episode: 2820, avg score: 9.2
# # of episode: 2840, avg score: 9.4
# # of episode: 2860, avg score: 9.3
# # of episode: 2880, avg score: 9.3
# # of episode: 2900, avg score: 9.5
# # of episode: 2920, avg score: 9.3
# # of episode: 2940, avg score: 9.4
# # of episode: 2960, avg score: 9.3
# # of episode: 2980, avg score: 9.6
# # of episode: 3000, avg score: 9.7
# # of episode: 3020, avg score: 9.3
# # of episode: 3040, avg score: 9.6
# # of episode: 3060, avg score: 9.6
# # of episode: 3080, avg score: 8.9
# # of episode: 3100, avg score: 9.4
# # of episode: 3120, avg score: 9.3
# # of episode: 3140, avg score: 9.4
# # of episode: 3160, avg score: 9.2
# # of episode: 3180, avg score: 9.4
# # of episode: 3200, avg score: 9.4
# # of episode: 3220, avg score: 9.6
# # of episode: 3240, avg score: 9.3
# # of episode: 3260, avg score: 9.4
# # of episode: 3280, avg score: 9.3
# # of episode: 3300, avg score: 9.4
# # of episode: 3320, avg score: 9.3
# # of episode: 3340, avg score: 9.4
# # of episode: 3360, avg score: 9.4
# # of episode: 3380, avg score: 9.7
# # of episode: 3400, avg score: 9.2
# # of episode: 3420, avg score: 9.8
# # of episode: 3440, avg score: 9.2
# # of episode: 3460, avg score: 9.3
# # of episode: 3480, avg score: 9.3
# # of episode: 3500, avg score: 9.1
# # of episode: 3520, avg score: 9.6
# # of episode: 3540, avg score: 9.3
# # of episode: 3560, avg score: 9.4
# # of episode: 3580, avg score: 9.2
# # of episode: 3600, avg score: 9.5
# # of episode: 3620, avg score: 9.4
# # of episode: 3640, avg score: 9.5
# # of episode: 3660, avg score: 9.2
# # of episode: 3680, avg score: 9.4
# # of episode: 3700, avg score: 9.3
# # of episode: 3720, avg score: 9.6
# # of episode: 3740, avg score: 9.3
# # of episode: 3760, avg score: 9.2
# # of episode: 3780, avg score: 9.7
# # of episode: 3800, avg score: 9.1
# # of episode: 3820, avg score: 9.6
# # of episode: 3840, avg score: 9.3
# # of episode: 3860, avg score: 9.2
# # of episode: 3880, avg score: 9.4
# # of episode: 3900, avg score: 9.2
# # of episode: 3920, avg score: 9.1
# # of episode: 3940, avg score: 9.3
# # of episode: 3960, avg score: 9.5
# # of episode: 3980, avg score: 9.6
# # of episode: 4000, avg score: 9.4
# # of episode: 4020, avg score: 9.2
# # of episode: 4040, avg score: 9.3
# # of episode: 4060, avg score: 9.6
# # of episode: 4080, avg score: 9.4
# # of episode: 4100, avg score: 9.6
# # of episode: 4120, avg score: 9.2
# # of episode: 4140, avg score: 9.1
# # of episode: 4160, avg score: 9.4
# # of episode: 4180, avg score: 9.1
# # of episode: 4200, avg score: 9.3
# # of episode: 4220, avg score: 9.3
# # of episode: 4240, avg score: 9.5
# # of episode: 4260, avg score: 9.3
# # of episode: 4280, avg score: 9.4
# # of episode: 4300, avg score: 9.7
# # of episode: 4320, avg score: 9.7
# # of episode: 4340, avg score: 9.3
# # of episode: 4360, avg score: 9.3
# # of episode: 4380, avg score: 9.4
# # of episode: 4400, avg score: 9.3
# # of episode: 4420, avg score: 9.0
# # of episode: 4440, avg score: 9.6
# # of episode: 4460, avg score: 9.6
# # of episode: 4480, avg score: 9.2
# # of episode: 4500, avg score: 9.2
# # of episode: 4520, avg score: 9.2
# # of episode: 4540, avg score: 9.5
# # of episode: 4560, avg score: 9.4
# # of episode: 4580, avg score: 9.3
# # of episode: 4600, avg score: 9.7
# # of episode: 4620, avg score: 9.3
# # of episode: 4640, avg score: 9.2
# # of episode: 4660, avg score: 9.6
# # of episode: 4680, avg score: 9.2
# # of episode: 4700, avg score: 9.4
# # of episode: 4720, avg score: 9.3
# # of episode: 4740, avg score: 9.4
# # of episode: 4760, avg score: 9.2
# # of episode: 4780, avg score: 9.2
# # of episode: 4800, avg score: 9.2
# # of episode: 4820, avg score: 9.5
# # of episode: 4840, avg score: 9.8
# # of episode: 4860, avg score: 9.6
# # of episode: 4880, avg score: 9.3
# # of episode: 4900, avg score: 9.5
# # of episode: 4920, avg score: 9.2
# # of episode: 4940, avg score: 9.3
# # of episode: 4960, avg score: 9.6
# # of episode: 4980, avg score: 9.4
# # of episode: 5000, avg score: 9.5
# # of episode: 5020, avg score: 9.1
# # of episode: 5040, avg score: 9.3
# # of episode: 5060, avg score: 9.4
# # of episode: 5080, avg score: 9.3
# # of episode: 5100, avg score: 9.2
# # of episode: 5120, avg score: 9.3
# # of episode: 5140, avg score: 9.4
# # of episode: 5160, avg score: 9.1
# # of episode: 5180, avg score: 9.4
# # of episode: 5200, avg score: 9.4
# # of episode: 5220, avg score: 9.8
# # of episode: 5240, avg score: 9.3
# # of episode: 5260, avg score: 9.3
# # of episode: 5280, avg score: 9.4
# # of episode: 5300, avg score: 9.2
# # of episode: 5320, avg score: 9.2
# # of episode: 5340, avg score: 9.3
# # of episode: 5360, avg score: 9.4
# # of episode: 5380, avg score: 9.4
# # of episode: 5400, avg score: 9.6
# # of episode: 5420, avg score: 9.2
# # of episode: 5440, avg score: 9.4
# # of episode: 5460, avg score: 9.3
# # of episode: 5480, avg score: 9.6
# # of episode: 5500, avg score: 9.3
# # of episode: 5520, avg score: 9.2
# # of episode: 5540, avg score: 9.6
# # of episode: 5560, avg score: 9.2
# # of episode: 5580, avg score: 9.3
# # of episode: 5600, avg score: 9.6
# # of episode: 5620, avg score: 9.3
# # of episode: 5640, avg score: 9.3
# # of episode: 5660, avg score: 9.4
# # of episode: 5680, avg score: 9.2
# # of episode: 5700, avg score: 9.6
# # of episode: 5720, avg score: 9.4
# # of episode: 5740, avg score: 9.4
# # of episode: 5760, avg score: 9.2
# # of episode: 5780, avg score: 9.6
# # of episode: 5800, avg score: 9.7
# # of episode: 5820, avg score: 9.4
# # of episode: 5840, avg score: 9.4
# # of episode: 5860, avg score: 9.4
# # of episode: 5880, avg score: 9.4
# # of episode: 5900, avg score: 9.4
# # of episode: 5920, avg score: 9.4
# # of episode: 5940, avg score: 9.7
# # of episode: 5960, avg score: 9.4
# # of episode: 5980, avg score: 9.3
# # of episode: 6000, avg score: 9.4
# # of episode: 6020, avg score: 9.2
# # of episode: 6040, avg score: 9.4
# # of episode: 6060, avg score: 9.3
# # of episode: 6080, avg score: 9.5
# # of episode: 6100, avg score: 9.7
# # of episode: 6120, avg score: 9.4
# # of episode: 6140, avg score: 9.2
# # of episode: 6160, avg score: 9.4
# # of episode: 6180, avg score: 9.3
# # of episode: 6200, avg score: 9.3
# # of episode: 6220, avg score: 9.2
# # of episode: 6240, avg score: 9.2
# # of episode: 6260, avg score: 9.0
# # of episode: 6280, avg score: 9.5
# # of episode: 6300, avg score: 9.3
# # of episode: 6320, avg score: 9.4
# # of episode: 6340, avg score: 9.4
# # of episode: 6360, avg score: 9.4
# # of episode: 6380, avg score: 9.6
# # of episode: 6400, avg score: 9.6
# # of episode: 6420, avg score: 9.5
# # of episode: 6440, avg score: 9.2
# # of episode: 6460, avg score: 9.3
# # of episode: 6480, avg score: 9.8
# # of episode: 6500, avg score: 9.2
# # of episode: 6520, avg score: 9.6
# # of episode: 6540, avg score: 9.3
# # of episode: 6560, avg score: 8.9
# # of episode: 6580, avg score: 9.3
# # of episode: 6600, avg score: 9.3
# # of episode: 6620, avg score: 9.5
# # of episode: 6640, avg score: 9.4
# # of episode: 6660, avg score: 9.3
# # of episode: 6680, avg score: 9.2
# # of episode: 6700, avg score: 9.4
# # of episode: 6720, avg score: 9.4
# # of episode: 6740, avg score: 9.3
# # of episode: 6760, avg score: 9.3
# # of episode: 6780, avg score: 9.2
# # of episode: 6800, avg score: 9.4
# # of episode: 6820, avg score: 9.3
# # of episode: 6840, avg score: 9.0
# # of episode: 6860, avg score: 9.3
# # of episode: 6880, avg score: 9.3
# # of episode: 6900, avg score: 9.5
# # of episode: 6920, avg score: 9.3
# # of episode: 6940, avg score: 9.1
# # of episode: 6960, avg score: 9.3
# # of episode: 6980, avg score: 9.5
# # of episode: 7000, avg score: 9.3
# # of episode: 7020, avg score: 9.2
# # of episode: 7040, avg score: 9.2
# # of episode: 7060, avg score: 9.2
# # of episode: 7080, avg score: 9.6
# # of episode: 7100, avg score: 9.1
# # of episode: 7120, avg score: 9.4
# # of episode: 7140, avg score: 9.2
# # of episode: 7160, avg score: 9.2
# # of episode: 7180, avg score: 9.3
# # of episode: 7200, avg score: 9.2
# # of episode: 7220, avg score: 9.5
# # of episode: 7240, avg score: 9.3
# # of episode: 7260, avg score: 9.2
# # of episode: 7280, avg score: 9.2
# # of episode: 7300, avg score: 9.6
# # of episode: 7320, avg score: 9.2
# # of episode: 7340, avg score: 9.2
# # of episode: 7360, avg score: 9.3
# # of episode: 7380, avg score: 9.5
# # of episode: 7400, avg score: 9.4
# # of episode: 7420, avg score: 9.1
# # of episode: 7440, avg score: 9.2
# # of episode: 7460, avg score: 9.0
# # of episode: 7480, avg score: 9.6
# # of episode: 7500, avg score: 9.4
# # of episode: 7520, avg score: 9.2
# # of episode: 7540, avg score: 9.8
# # of episode: 7560, avg score: 9.3
# # of episode: 7580, avg score: 9.7
# # of episode: 7600, avg score: 9.1
# # of episode: 7620, avg score: 9.2
# # of episode: 7640, avg score: 9.4
# # of episode: 7660, avg score: 9.3
# # of episode: 7680, avg score: 9.4
# # of episode: 7700, avg score: 9.3
# # of episode: 7720, avg score: 9.5
# # of episode: 7740, avg score: 9.2
# # of episode: 7760, avg score: 9.2
# # of episode: 7780, avg score: 9.4
# # of episode: 7800, avg score: 9.2
# # of episode: 7820, avg score: 9.8
# # of episode: 7840, avg score: 9.3
# # of episode: 7860, avg score: 9.3
# # of episode: 7880, avg score: 9.4
# # of episode: 7900, avg score: 9.1
# # of episode: 7920, avg score: 9.4
# # of episode: 7940, avg score: 9.3
# # of episode: 7960, avg score: 9.2
# # of episode: 7980, avg score: 9.9
# # of episode: 8000, avg score: 9.4
# # of episode: 8020, avg score: 9.5
# # of episode: 8040, avg score: 9.2
# # of episode: 8060, avg score: 9.7
# # of episode: 8080, avg score: 9.6
# # of episode: 8100, avg score: 9.2
# # of episode: 8120, avg score: 9.4
# # of episode: 8140, avg score: 9.4
# # of episode: 8160, avg score: 9.2
# # of episode: 8180, avg score: 9.5
# # of episode: 8200, avg score: 9.2
# # of episode: 8220, avg score: 9.6
# # of episode: 8240, avg score: 9.3
# # of episode: 8260, avg score: 9.2
# # of episode: 8280, avg score: 9.7
# # of episode: 8300, avg score: 9.4
# # of episode: 8320, avg score: 9.4
# # of episode: 8340, avg score: 9.2
# # of episode: 8360, avg score: 9.4
# # of episode: 8380, avg score: 9.3
# # of episode: 8400, avg score: 9.6
# # of episode: 8420, avg score: 9.3
# # of episode: 8440, avg score: 9.1
# # of episode: 8460, avg score: 9.3
# # of episode: 8480, avg score: 9.3
# # of episode: 8500, avg score: 9.4
# # of episode: 8520, avg score: 9.4
# # of episode: 8540, avg score: 9.4
# # of episode: 8560, avg score: 9.4
# # of episode: 8580, avg score: 9.2
# # of episode: 8600, avg score: 9.2
# # of episode: 8620, avg score: 9.3
# # of episode: 8640, avg score: 9.3
# # of episode: 8660, avg score: 9.4
# # of episode: 8680, avg score: 9.3
# # of episode: 8700, avg score: 9.2
# # of episode: 8720, avg score: 9.1
# # of episode: 8740, avg score: 9.2
# # of episode: 8760, avg score: 9.3
# # of episode: 8780, avg score: 9.6
# # of episode: 8800, avg score: 9.2
# # of episode: 8820, avg score: 9.7
# # of episode: 8840, avg score: 9.3
# # of episode: 8860, avg score: 9.4
# # of episode: 8880, avg score: 9.6
# # of episode: 8900, avg score: 9.2
# # of episode: 8920, avg score: 9.2
# # of episode: 8940, avg score: 9.6
# # of episode: 8960, avg score: 9.6
# # of episode: 8980, avg score: 9.7
# # of episode: 9000, avg score: 9.3
# # of episode: 9020, avg score: 9.4
# # of episode: 9040, avg score: 9.3
# # of episode: 9060, avg score: 9.3
# # of episode: 9080, avg score: 9.4
# # of episode: 9100, avg score: 9.5
# # of episode: 9120, avg score: 9.2
# # of episode: 9140, avg score: 9.3
# # of episode: 9160, avg score: 9.4
# # of episode: 9180, avg score: 9.5
# # of episode: 9200, avg score: 9.4
# # of episode: 9220, avg score: 9.2
# # of episode: 9240, avg score: 9.5
# # of episode: 9260, avg score: 9.4
# # of episode: 9280, avg score: 9.3
# # of episode: 9300, avg score: 9.6
# # of episode: 9320, avg score: 9.3
# # of episode: 9340, avg score: 9.2
# # of episode: 9360, avg score: 9.2
# # of episode: 9380, avg score: 9.6
# # of episode: 9400, avg score: 9.2
# # of episode: 9420, avg score: 9.6
# # of episode: 9440, avg score: 9.3
# # of episode: 9460, avg score: 9.6
# # of episode: 9480, avg score: 9.4
# # of episode: 9500, avg score: 9.5
# # of episode: 9520, avg score: 9.2
# # of episode: 9540, avg score: 9.6
# # of episode: 9560, avg score: 9.2
# # of episode: 9580, avg score: 9.4
# # of episode: 9600, avg score: 9.4
# # of episode: 9620, avg score: 9.2
# # of episode: 9640, avg score: 9.4
# # of episode: 9660, avg score: 9.3
# # of episode: 9680, avg score: 9.4
# # of episode: 9700, avg score: 9.3
# # of episode: 9720, avg score: 9.6
# # of episode: 9740, avg score: 9.4
# # of episode: 9760, avg score: 9.3
# # of episode: 9780, avg score: 9.5
# # of episode: 9800, avg score: 9.2
# # of episode: 9820, avg score: 9.4
# # of episode: 9840, avg score: 9.4
# # of episode: 9860, avg score: 9.3
# # of episode: 9880, avg score: 9.1
# # of episode: 9900, avg score: 9.2
# # of episode: 9920, avg score: 9.3
# # of episode: 9940, avg score: 9.4
# # of episode: 9960, avg score: 9.7
# # of episode: 9980, avg score: 9.2

# %%
def main():
    env = gym.make("CartPole-v0")
    model = PPO()
    score = 0.0
    print_interval = 20

    for n_epi in range(10000):
        s = env.reset()
        done = False
        while not done:
            for t in range(T_horizon):
                prob = model.pi(torch.from_numpy(s).float())
                m = Categorical(prob)
                a = m.sample().item()
                s_prime, r, done, _ = env.step(a)

                model.put_data((s, a, r / 100.0, s_prime, prob[a].item(), done))
                s = s_prime
                score += r

                if done:
                    break

            model.train_net()

        if n_epi % print_interval == 0 and n_epi != 0:
            print("# of episode: {}, avg score: {:.1f}".format(n_epi, score / print_interval))
            score = 0.0

    env.close()

# %%
if __name__ == "__main__":
    main()
# Out:
# # of episode: 20, avg score: 24.9
# # of episode: 40, avg score: 23.4
# # of episode: 60, avg score: 19.8
# # of episode: 80, avg score: 18.9
# # of episode: 100, avg score: 15.9
# # of episode: 120, avg score: 16.1
# # of episode: 140, avg score: 14.0
# # of episode: 160, avg score: 17.4
# # of episode: 180, avg score: 16.3
# # of episode: 200, avg score: 17.1
# # of episode: 220, avg score: 17.8
# # of episode: 240, avg score: 13.3
# # of episode: 260, avg score: 13.6
# # of episode: 280, avg score: 16.2
# # of episode: 300, avg score: 13.2
# # of episode: 320, avg score: 13.9
# # of episode: 340, avg score: 15.2
# # of episode: 360, avg score: 14.3
# # of episode: 380, avg score: 11.8
# # of episode: 400, avg score: 11.0
# # of episode: 420, avg score: 11.9
# # of episode: 440, avg score: 10.9
# # of episode: 460, avg score: 12.6
# # of episode: 480, avg score: 12.2
# # of episode: 500, avg score: 11.6
# # of episode: 520, avg score: 11.2
# # of episode: 540, avg score: 10.8
# # of episode: 560, avg score: 10.4
# # of episode: 580, avg score: 10.6
# # of episode: 600, avg score: 11.5
# # of episode: 620, avg score: 9.8
# # of episode: 640, avg score: 10.8
# # of episode: 660, avg score: 11.0
# # of episode: 680, avg score: 9.9
# # of episode: 700, avg score: 11.3
# # of episode: 720, avg score: 10.3
# # of episode: 740, avg score: 9.9
# # of episode: 760, avg score: 9.8
# # of episode: 780, avg score: 9.8
# # of episode: 800, avg score: 9.8
# # of episode: 820, avg score: 10.9
# # of episode: 840, avg score: 10.7
# # of episode: 860, avg score: 10.7
# # of episode: 880, avg score: 9.9
# # of episode: 900, avg score: 10.2
# # of episode: 920, avg score: 10.1
# # of episode: 940, avg score: 10.2
# # of episode: 960, avg score: 9.6
# # of episode: 980, avg score: 11.0
# # of episode: 1000, avg score: 10.1
# # of episode: 1020, avg score: 10.1
# # of episode: 1040, avg score: 9.8
# # of episode: 1060, avg score: 9.8
# # of episode: 1080, avg score: 10.3
# # of episode: 1100, avg score: 9.8
# # of episode: 1120, avg score: 9.8
# # of episode: 1140, avg score: 10.4
# # of episode: 1160, avg score: 9.6
# # of episode: 1180, avg score: 10.3
# # of episode: 1200, avg score: 9.7
# # of episode: 1220, avg score: 9.7
# # of episode: 1240, avg score: 9.6
# # of episode: 1260, avg score: 9.8
# # of episode: 1280, avg score: 9.7
# # of episode: 1300, avg score: 10.4
# # of episode: 1320, avg score: 9.8
# # of episode: 1340, avg score: 10.4
# # of episode: 1360, avg score: 9.7
# # of episode: 1380, avg score: 9.8
# # of episode: 1400, avg score: 9.7
# # of episode: 1420, avg score: 9.4
# # of episode: 1440, avg score: 10.1
# # of episode: 1460, avg score: 9.4
# # of episode: 1480, avg score: 9.6
# # of episode: 1500, avg score: 9.4
# # of episode: 1520, avg score: 9.8
# # of episode: 1540, avg score: 9.6
# # of episode: 1560, avg score: 9.6
# # of episode: 1580, avg score: 9.3
# # of episode: 1600, avg score: 9.4
# # of episode: 1620, avg score: 9.1
# # of episode: 1640, avg score: 9.7
# # of episode: 1660, avg score: 9.3
# # of episode: 1680, avg score: 9.4
# # of episode: 1700, avg score: 9.4
# # of episode: 1720, avg score: 9.6
# # of episode: 1740, avg score: 9.6
# # of episode: 1760, avg score: 9.3
# # of episode: 1780, avg score: 9.3
# # of episode: 1800, avg score: 9.3
# # of episode: 1820, avg score: 9.8
# # of episode: 1840, avg score: 9.8
# # of episode: 1860, avg score: 9.4
# # of episode: 1880, avg score: 9.4
# # of episode: 1900, avg score: 9.7
# # of episode: 1920, avg score: 9.3
# # of episode: 1940, avg score: 9.3
# # of episode: 1960, avg score: 9.2
# # of episode: 1980, avg score: 9.2
# # of episode: 2000, avg score: 9.4
# # of episode: 2020, avg score: 9.4
# # of episode: 2040, avg score: 9.8
# # of episode: 2060, avg score: 9.7
# # of episode: 2080, avg score: 9.8
# # of episode: 2100, avg score: 9.7
# # of episode: 2120, avg score: 9.2
# # of episode: 2140, avg score: 9.3
# # of episode: 2160, avg score: 9.4
# # of episode: 2180, avg score: 9.4
# # of episode: 2200, avg score: 9.5
# # of episode: 2220, avg score: 9.7
# # of episode: 2240, avg score: 9.1
# # of episode: 2260, avg score: 9.4
# # of episode: 2280, avg score: 9.8
# # of episode: 2300, avg score: 9.3
# # of episode: 2320, avg score: 9.3
# # of episode: 2340, avg score: 9.2
# # of episode: 2360, avg score: 9.7
# # of episode: 2380, avg score: 9.3
# # of episode: 2400, avg score: 9.6
# # of episode: 2420, avg score: 9.8
# # of episode: 2440, avg score: 9.1
# # of episode: 2460, avg score: 9.7
# # of episode: 2480, avg score: 9.2
# # of episode: 2500, avg score: 9.6
# # of episode: 2520, avg score: 9.3
# # of episode: 2540, avg score: 9.6
# # of episode: 2560, avg score: 9.5
# # of episode: 2580, avg score: 9.6
# # of episode: 2600, avg score: 9.2
# # of episode: 2620, avg score: 9.2
# # of episode: 2640, avg score: 9.4
# # of episode: 2660, avg score: 9.4
# # of episode: 2680, avg score: 9.6
# # of episode: 2700, avg score: 9.3
# # of episode: 2720, avg score: 9.7
# # of episode: 2740, avg score: 9.6
# # of episode: 2760, avg score: 9.8
# # of episode: 2780, avg score: 9.4
# # of episode: 2800, avg score: 9.2
# # of episode: 2820, avg score: 9.2
# # of episode: 2840, avg score: 9.2
# # of episode: 2860, avg score: 9.5
# # of episode: 2880, avg score: 9.2
# # of episode: 2900, avg score: 9.3
# # of episode: 2920, avg score: 9.5
# # of episode: 2940, avg score: 9.4
# # of episode: 2960, avg score: 9.2
# # of episode: 2980, avg score: 9.2
# # of episode: 3000, avg score: 9.3
# # of episode: 3020, avg score: 9.1
# # of episode: 3040, avg score: 9.1
# # of episode: 3060, avg score: 9.5
# # of episode: 3080, avg score: 9.4
# # of episode: 3100, avg score: 9.4
# # of episode: 3120, avg score: 9.4
# # of episode: 3140, avg score: 9.2
# # of episode: 3160, avg score: 9.4
# # of episode: 3180, avg score: 9.5
# # of episode: 3200, avg score: 9.2
# # of episode: 3220, avg score: 9.9
# # of episode: 3240, avg score: 9.3
# # of episode: 3260, avg score: 9.3
# # of episode: 3280, avg score: 9.3
# # of episode: 3300, avg score: 9.5
# # of episode: 3320, avg score: 9.6
# # of episode: 3340, avg score: 9.3
# # of episode: 3360, avg score: 9.2
# # of episode: 3380, avg score: 9.3
# # of episode: 3400, avg score: 9.7
# # of episode: 3420, avg score: 9.2
# # of episode: 3440, avg score: 9.4
# # of episode: 3460, avg score: 9.4
# # of episode: 3480, avg score: 9.4
# # of episode: 3500, avg score: 9.4
# # of episode: 3520, avg score: 9.3
# # of episode: 3540, avg score: 9.3
# # of episode: 3560, avg score: 9.6
# # of episode: 3580, avg score: 9.4
# # of episode: 3600, avg score: 9.3
# # of episode: 3620, avg score: 9.3
# # of episode: 3640, avg score: 9.3
# # of episode: 3660, avg score: 9.1
# # of episode: 3680, avg score: 9.2
# # of episode: 3700, avg score: 9.4
# # of episode: 3720, avg score: 9.4
# # of episode: 3740, avg score: 9.3
# # of episode: 3760, avg score: 9.6
# # of episode: 3780, avg score: 9.2
# # of episode: 3800, avg score: 9.3
# # of episode: 3820, avg score: 9.3
# # of episode: 3840, avg score: 9.6
# # of episode: 3860, avg score: 9.2
# # of episode: 3880, avg score: 9.1
# # of episode: 3900, avg score: 9.3
# # of episode: 3920, avg score: 8.9
# # of episode: 3940, avg score: 9.4
# # of episode: 3960, avg score: 9.3
# # of episode: 3980, avg score: 9.7
# # of episode: 4000, avg score: 9.6
# # of episode: 4020, avg score: 9.5
# # of episode: 4040, avg score: 9.3
# # of episode: 4060, avg score: 9.6
# # of episode: 4080, avg score: 9.4
# # of episode: 4100, avg score: 9.2
# # of episode: 4120, avg score: 9.3
# # of episode: 4140, avg score: 9.3
# # of episode: 4160, avg score: 9.2
# # of episode: 4180, avg score: 9.4
# # of episode: 4200, avg score: 9.4
# # of episode: 4220, avg score: 9.3
# # of episode: 4240, avg score: 9.4
# # of episode: 4260, avg score: 9.3
# # of episode: 4280, avg score: 9.4
# # of episode: 4300, avg score: 9.1
# # of episode: 4320, avg score: 9.3
# # of episode: 4340, avg score: 9.3
# # of episode: 4360, avg score: 9.4
# # of episode: 4380, avg score: 9.3
# # of episode: 4400, avg score: 9.1
# # of episode: 4420, avg score: 9.6
# # of episode: 4440, avg score: 9.8
# # of episode: 4460, avg score: 9.2
# # of episode: 4480, avg score: 9.5
# # of episode: 4500, avg score: 9.7
# # of episode: 4520, avg score: 9.3
# # of episode: 4540, avg score: 9.4
# # of episode: 4560, avg score: 9.2
# # of episode: 4580, avg score: 9.6
# # of episode: 4600, avg score: 9.6
# # of episode: 4620, avg score: 9.5
# # of episode: 4640, avg score: 9.3
# # of episode: 4660, avg score: 9.4
# # of episode: 4680, avg score: 9.3
# # of episode: 4700, avg score: 9.4
# # of episode: 4720, avg score: 9.6
# # of episode: 4740, avg score: 9.5
# # of episode: 4760, avg score: 9.4
# # of episode: 4780, avg score: 9.2
# # of episode: 4800, avg score: 9.2
# # of episode: 4820, avg score: 9.0
# # of episode: 4840, avg score: 9.7
# # of episode: 4860, avg score: 9.2
# # of episode: 4880, avg score: 9.5
# # of episode: 4900, avg score: 9.7
# # of episode: 4920, avg score: 9.6
# # of episode: 4940, avg score: 9.2
# # of episode: 4960, avg score: 9.4
# # of episode: 4980, avg score: 9.4
# # of episode: 5000, avg score: 9.7
# # of episode: 5020, avg score: 9.2
# # of episode: 5040, avg score: 9.2
# # of episode: 5060, avg score: 9.5
# # of episode: 5080, avg score: 9.4
# # of episode: 5100, avg score: 9.2
# # of episode: 5120, avg score: 9.3
# # of episode: 5140, avg score: 9.6
# # of episode: 5160, avg score: 9.6
# # of episode: 5180, avg score: 9.6
# # of episode: 5200, avg score: 9.4
# # of episode: 5220, avg score: 9.3
# # of episode: 5240, avg score: 9.3
# # of episode: 5260, avg score: 9.8
# # of episode: 5280, avg score: 9.1
# # of episode: 5300, avg score: 9.3
# # of episode: 5320, avg score: 9.5
# # of episode: 5340, avg score: 9.4
# # of episode: 5360, avg score: 8.9
# # of episode: 5380, avg score: 9.7
# # of episode: 5400, avg score: 9.4
# # of episode: 5420, avg score: 9.4
# # of episode: 5440, avg score: 9.2
# # of episode: 5460, avg score: 9.2
# # of episode: 5480, avg score: 9.3
# # of episode: 5500, avg score: 9.4
# # of episode: 5520, avg score: 9.2
# # of episode: 5540, avg score: 9.7
# # of episode: 5560, avg score: 9.1
# # of episode: 5580, avg score: 9.7
# # of episode: 5600, avg score: 8.9
# # of episode: 5620, avg score: 9.4
# # of episode: 5640, avg score: 9.4
# # of episode: 5660, avg score: 9.4
# # of episode: 5680, avg score: 9.2
# # of episode: 5700, avg score: 9.2
# # of episode: 5720, avg score: 9.6
# # of episode: 5740, avg score: 9.3
# # of episode: 5760, avg score: 9.5
# # of episode: 5780, avg score: 9.7
# # of episode: 5800, avg score: 9.2
# # of episode: 5820, avg score: 9.1
# # of episode: 5840, avg score: 9.4
# # of episode: 5860, avg score: 9.3
# # of episode: 5880, avg score: 9.7
# # of episode: 5900, avg score: 9.2
# # of episode: 5920, avg score: 9.3
# # of episode: 5940, avg score: 9.6
# # of episode: 5960, avg score: 9.4
# # of episode: 5980, avg score: 9.6
# # of episode: 6000, avg score: 9.3
# # of episode: 6020, avg score: 9.3
# # of episode: 6040, avg score: 9.4
# # of episode: 6060, avg score: 9.2
# # of episode: 6080, avg score: 9.5
# # of episode: 6100, avg score: 9.7
# # of episode: 6120, avg score: 9.3
# # of episode: 6140, avg score: 9.4
# # of episode: 6160, avg score: 9.6
# # of episode: 6180, avg score: 9.2
# # of episode: 6200, avg score: 9.5
# # of episode: 6220, avg score: 9.5
# # of episode: 6240, avg score: 9.1
# # of episode: 6260, avg score: 9.2
# # of episode: 6280, avg score: 9.6
# # of episode: 6300, avg score: 9.3
# # of episode: 6320, avg score: 9.7
# # of episode: 6340, avg score: 9.4
# # of episode: 6360, avg score: 9.0
# # of episode: 6380, avg score: 9.4
# # of episode: 6400, avg score: 9.4
# # of episode: 6420, avg score: 9.4
# # of episode: 6440, avg score: 9.2
# # of episode: 6460, avg score: 9.2
# # of episode: 6480, avg score: 9.3
# # of episode: 6500, avg score: 9.4
# # of episode: 6520, avg score: 9.2
# # of episode: 6540, avg score: 9.8
# # of episode: 6560, avg score: 9.6
# # of episode: 6580, avg score: 9.2
# # of episode: 6600, avg score: 9.5
# # of episode: 6620, avg score: 9.4
# # of episode: 6640, avg score: 9.7
# # of episode: 6660, avg score: 9.2
# # of episode: 6680, avg score: 9.1
# # of episode: 6700, avg score: 9.3
# # of episode: 6720, avg score: 9.4
# # of episode: 6740, avg score: 9.3
# # of episode: 6760, avg score: 9.6
# # of episode: 6780, avg score: 9.3
# # of episode: 6800, avg score: 9.7
# # of episode: 6820, avg score: 9.4
# # of episode: 6840, avg score: 9.4
# # of episode: 6860, avg score: 9.4
# # of episode: 6880, avg score: 9.3
# # of episode: 6900, avg score: 9.2
# # of episode: 6920, avg score: 9.2
# # of episode: 6940, avg score: 9.2
# # of episode: 6960, avg score: 9.2
# # of episode: 6980, avg score: 9.4
# # of episode: 7000, avg score: 9.2
# # of episode: 7020, avg score: 9.4
# # of episode: 7040, avg score: 9.2
# # of episode: 7060, avg score: 9.7
# # of episode: 7080, avg score: 9.3
# # of episode: 7100, avg score: 9.5
# # of episode: 7120, avg score: 9.3
# # of episode: 7140, avg score: 9.6
# # of episode: 7160, avg score: 9.6
# # of episode: 7180, avg score: 8.9
# # of episode: 7200, avg score: 9.7
# # of episode: 7220, avg score: 9.1
# # of episode: 7240, avg score: 9.2
# # of episode: 7260, avg score: 9.2
# # of episode: 7280, avg score: 9.6
# # of episode: 7300, avg score: 9.3
# # of episode: 7320, avg score: 9.4
# # of episode: 7340, avg score: 9.5
# # of episode: 7360, avg score: 9.3
# # of episode: 7380, avg score: 9.6
# # of episode: 7400, avg score: 9.5
# # of episode: 7420, avg score: 9.2
# # of episode: 7440, avg score: 9.3
# # of episode: 7460, avg score: 9.8
# # of episode: 7480, avg score: 9.4
# # of episode: 7500, avg score: 9.4
# # of episode: 7520, avg score: 9.5
# # of episode: 7540, avg score: 9.3
# # of episode: 7560, avg score: 9.3
# # of episode: 7580, avg score: 9.4
# # of episode: 7600, avg score: 9.2
# # of episode: 7620, avg score: 9.3
# # of episode: 7640, avg score: 9.2
# # of episode: 7660, avg score: 9.5
# # of episode: 7680, avg score: 9.7
# # of episode: 7700, avg score: 9.3
# # of episode: 7720, avg score: 9.7
# # of episode: 7740, avg score: 9.4
# # of episode: 7760, avg score: 9.2
# # of episode: 7780, avg score: 9.3
# # of episode: 7800, avg score: 9.3
# # of episode: 7820, avg score: 9.3
# # of episode: 7840, avg score: 9.5
# # of episode: 7860, avg score: 9.2
# # of episode: 7880, avg score: 9.7
# # of episode: 7900, avg score: 9.4
# # of episode: 7920, avg score: 9.6
# # of episode: 7940, avg score: 9.3
# # of episode: 7960, avg score: 9.3
# # of episode: 7980, avg score: 9.5
# # of episode: 8000, avg score: 9.2
# # of episode: 8020, avg score: 9.5
# # of episode: 8040, avg score: 9.2
# # of episode: 8060, avg score: 9.6
# # of episode: 8080, avg score: 9.5
# # of episode: 8100, avg score: 9.4
# # of episode: 8120, avg score: 9.2
# # of episode: 8140, avg score: 9.1
# # of episode: 8160, avg score: 9.2
# # of episode: 8180, avg score: 9.4
# # of episode: 8200, avg score: 9.5
# # of episode: 8220, avg score: 9.4
# # of episode: 8240, avg score: 9.3
# # of episode: 8260, avg score: 9.5
# # of episode: 8280, avg score: 9.7
# # of episode: 8300, avg score: 9.1
# # of episode: 8320, avg score: 9.6
# # of episode: 8340, avg score: 9.4
# # of episode: 8360, avg score: 9.7
# # of episode: 8380, avg score: 9.6
# # of episode: 8400, avg score: 9.5
# # of episode: 8420, avg score: 9.3
# # of episode: 8440, avg score: 9.4
# # of episode: 8460, avg score: 9.2
# # of episode: 8480, avg score: 9.3
# # of episode: 8500, avg score: 9.3
# # of episode: 8520, avg score: 9.6
# # of episode: 8540, avg score: 9.4
# # of episode: 8560, avg score: 9.4
# # of episode: 8580, avg score: 9.4
# # of episode: 8600, avg score: 9.3
# # of episode: 8620, avg score: 9.6
# # of episode: 8640, avg score: 9.7
# # of episode: 8660, avg score: 9.6
# # of episode: 8680, avg score: 9.2
# # of episode: 8700, avg score: 9.6
# # of episode: 8720, avg score: 9.4
# # of episode: 8740, avg score: 9.5
# # of episode: 8760, avg score: 9.2
# # of episode: 8780, avg score: 9.6
# # of episode: 8800, avg score: 9.2
# # of episode: 8820, avg score: 9.6
# # of episode: 8840, avg score: 9.6
# # of episode: 8860, avg score: 9.5
# # of episode: 8880, avg score: 9.5
# # of episode: 8900, avg score: 9.3
# # of episode: 8920, avg score: 9.3
# # of episode: 8940, avg score: 9.3
# # of episode: 8960, avg score: 9.1
# # of episode: 8980, avg score: 9.1
# # of episode: 9000, avg score: 9.2
# # of episode: 9020, avg score: 9.3
# # of episode: 9040, avg score: 9.4
# # of episode: 9060, avg score: 9.2
# # of episode: 9080, avg score: 9.2
# # of episode: 9100, avg score: 9.7
# # of episode: 9120, avg score: 9.3
# # of episode: 9140, avg score: 9.3
# # of episode: 9160, avg score: 9.3
# # of episode: 9180, avg score: 9.2
# # of episode: 9200, avg score: 9.4
# # of episode: 9220, avg score: 9.7
# # of episode: 9240, avg score: 9.5
# # of episode: 9260, avg score: 9.3
# # of episode: 9280, avg score: 9.2
# # of episode: 9300, avg score: 9.2
# # of episode: 9320, avg score: 9.6
# # of episode: 9340, avg score: 9.3
# # of episode: 9360, avg score: 9.3
# # of episode: 9380, avg score: 9.2
# # of episode: 9400, avg score: 9.4
# # of episode: 9420, avg score: 9.2
# # of episode: 9440, avg score: 9.0
# # of episode: 9460, avg score: 9.4
# # of episode: 9480, avg score: 9.2
# # of episode: 9500, avg score: 9.3
# # of episode: 9520, avg score: 9.2
# # of episode: 9540, avg score: 9.5
# # of episode: 9560, avg score: 9.8
# # of episode: 9580, avg score: 9.6
# # of episode: 9600, avg score: 9.5
# # of episode: 9620, avg score: 9.3
# # of episode: 9640, avg score: 9.2
# # of episode: 9660, avg score: 9.4
# # of episode: 9680, avg score: 9.1
# # of episode: 9700, avg score: 9.4
# # of episode: 9720, avg score: 9.3
# # of episode: 9740, avg score: 9.9
# # of episode: 9760, avg score: 9.3
# # of episode: 9780, avg score: 9.4
# # of episode: 9800, avg score: 9.2
# # of episode: 9820, avg score: 9.3
# # of episode: 9840, avg score: 9.4
# # of episode: 9860, avg score: 9.2
# # of episode: 9880, avg score: 9.7
# # of episode: 9900, avg score: 9.1
# # of episode: 9920, avg score: 9.6
# # of episode: 9940, avg score: 9.5
# # of episode: 9960, avg score: 9.5
# # of episode: 9980, avg score: 8.9
